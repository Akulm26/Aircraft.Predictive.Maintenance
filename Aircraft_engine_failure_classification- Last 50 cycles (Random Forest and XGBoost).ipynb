# %%
#necessary imports

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import xgboost as xgb
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier,GradientBoostingRegressor,GradientBoostingClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,r2_score,roc_auc_score,precision_score,recall_score,f1_score
from sklearn.model_selection import KFold,GridSearchCV,RandomizedSearchCV

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# %%
columns=["id","cycle","op1","op2","op3","sensor1","sensor2","sensor3","sensor4","sensor5","sensor6","sensor7","sensor8",
         "sensor9","sensor10","sensor11","sensor12","sensor13","sensor14","sensor15","sensor16","sensor17","sensor18","sensor19"
         ,"sensor20","sensor21","sensor22","sensor23"]

# %%
train_data = pd.read_csv("/Users/akulsuhailmalhotra/Desktop/AircraftPredictiveMaintenance/CMAPSSData/train_FD001.txt", sep= " ", names= columns)
test_data  = pd.read_csv ("/Users/akulsuhailmalhotra/Desktop/AircraftPredictiveMaintenance/CMAPSSData/test_FD001.txt",  sep= " ", names= columns)
test_results = pd.read_csv("/Users/akulsuhailmalhotra/Desktop/AircraftPredictiveMaintenance/CMAPSSData/RUL_FD001.txt", sep = " ", header = None)

# %%
#train_data.head
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 28 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        20631 non-null  int64
#  1   cycle     20631 non-null  int64
#  2   op1       20631 non-null  float64
#  3   op2       20631 non-null  float64
#  4   op3       20631 non-null  float64
#  5   sensor1   20631 non-null  float64
#  6   sensor2   20631 non-null  float64
#  7   sensor3   20631 non-null  float64
#  8   sensor4   20631 non-null  float64
#  9   sensor5   20631 non-null  float64
#  10  sensor6   20631 non-null  float64
#  11  sensor7   20631 non-null  float64
#  12  sensor8   20631 non-null  float64
#  13  sensor9   20631 non-null  float64
#  14  sensor10  20631 non-null  float64
#  15  sensor11  20631 non-null  float64
#  16  sensor12  20631 non-null  float64
#  17  sensor13  20631 non-null  float64
#  18  sensor14  20631 non-null  float64
# ...

# %%
#test_data.info()
test_data
# Out:
#         id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0        1      1  0.0023  0.0003  100.0   518.67   643.02  1585.29  1398.21
# 1        1      2 -0.0027 -0.0003  100.0   518.67   641.71  1588.45  1395.42
# 2        1      3  0.0003  0.0001  100.0   518.67   642.46  1586.94  1401.34
# 3        1      4  0.0042  0.0000  100.0   518.67   642.44  1584.12  1406.42
# 4        1      5  0.0014  0.0000  100.0   518.67   642.51  1587.19  1401.92
# ...    ...    ...     ...     ...    ...      ...      ...      ...      ...
# 13091  100    194  0.0049  0.0000  100.0   518.67   643.24  1599.45  1415.79
# 13092  100    195 -0.0011 -0.0001  100.0   518.67   643.22  1595.69  1422.05
# 13093  100    196 -0.0006 -0.0003  100.0   518.67   643.44  1593.15  1406.82
# 13094  100    197 -0.0038  0.0001  100.0   518.67   643.26  1594.99  1419.36
# 13095  100    198  0.0013  0.0003  100.0   518.67   642.95  1601.62  1424.99
#
# ...

# %%
#train_data.head()
#test_data.head()
#test_results.head()

# %%
## Engine Cycle Lifetime

#plt.style.use('dark_background')
plt.figure(figsize=(20,35))
ax=train_data.groupby('id')['cycle'].count().plot(kind='barh',width=0.8,align='center',rot=0, color = 'lightblue', stacked = True)
plt.title('Engines Lifetime',fontweight='bold',size=30)
plt.xlabel('Cycle Time',fontweight='bold',size=25)
plt.xticks(size=25)
plt.ylabel('Engine ID',fontweight='bold',size=25)
plt.yticks(size=25)
ax.axhline(0, color='grey', linewidth=0.8)
ax.bar_label(ax.containers[0], size = 20)
#ax.bar_label(ax.containers[1])
#plt.tight_layout()
plt.show()

# %%
## change test_results (actual RULs) column name 

test_results.columns=["rul","null"]
test_results.head()
# Out:
#    rul  null
# 0  112   NaN
# 1   98   NaN
# 2   69   NaN
# 3   82   NaN
# 4   91   NaN

# %%
# Dropping null values and adding the column 'id' which denotes engine IDs. The 'rul' column denotes actual values of remaining useful
# life of a particular aircraft engine. 

test_results.drop(["null"],axis=1,inplace=True)
test_results['id']=test_results.index+1
test_results.head()
# Out:
#    rul  id
# 0  112   1
# 1   98   2
# 2   69   3
# 3   82   4
# 4   91   5

# %%
sum(test_data['id'] == 1)
# Out:
# 31

# %%
##Computing max engine cycle in test_data - based on the number of observations per engine id. 

rul = pd.DataFrame(test_data.groupby('id')['cycle'].count()).reset_index()
rul.columns = ['id', 'max']
rul
# Out:
#      id  max
# 0     1   31
# 1     2   49
# 2     3  126
# 3     4  106
# 4     5   98
# ..  ...  ...
# 95   96   97
# 96   97  134
# 97   98  121
# 98   99   97
# 99  100  198
#
# [100 rows x 2 columns]

# %%
test_results['rul_failed'] = test_results['rul'] + rul['max']
test_results
# Out:
#     rul   id  rul_failed
# 0   112    1         143
# 1    98    2         147
# 2    69    3         195
# 3    82    4         188
# 4    91    5         189
# ..  ...  ...         ...
# 95  137   96         234
# 96   82   97         216
# 97   59   98         180
# 98  117   99         214
# 99   20  100         218
#
# [100 rows x 3 columns]

# %%
test_results.drop(["rul"],axis=1,inplace=True)
test_results.head()
# Out:
#    id  rul_failed
# 0   1         143
# 1   2         147
# 2   3         195
# 3   4         188
# 4   5         189

# %%
#run this code only once. 
test_data=test_data.merge(test_results,on=['id'],how='left')
test_data.head()
# Out:
#    id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0   1      1  0.0023  0.0003  100.0   518.67   643.02  1585.29  1398.21
# 1   1      2 -0.0027 -0.0003  100.0   518.67   641.71  1588.45  1395.42
# 2   1      3  0.0003  0.0001  100.0   518.67   642.46  1586.94  1401.34
# 3   1      4  0.0042  0.0000  100.0   518.67   642.44  1584.12  1406.42
# 4   1      5  0.0014  0.0000  100.0   518.67   642.51  1587.19  1401.92
#
#    sensor5  ...  sensor15  sensor16  sensor17  sensor18  sensor19  sensor20  \
# 0    14.62  ...    8.4052      0.03       392      2388     100.0     38.86
# 1    14.62  ...    8.3803      0.03       393      2388     100.0     39.02
# 2    14.62  ...    8.4441      0.03       393      2388     100.0     39.08
# 3    14.62  ...    8.3917      0.03       391      2388     100.0     39.00
# 4    14.62  ...    8.4031      0.03       390      2388     100.0     38.99
#
#    sensor21  sensor22  sensor23  rul_failed
# ...

# %%
test_data["remaining_cycle"]=test_data["rul_failed"]-test_data["cycle"]
test_data.head()
# Out:
#    id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0   1      1  0.0023  0.0003  100.0   518.67   643.02  1585.29  1398.21
# 1   1      2 -0.0027 -0.0003  100.0   518.67   641.71  1588.45  1395.42
# 2   1      3  0.0003  0.0001  100.0   518.67   642.46  1586.94  1401.34
# 3   1      4  0.0042  0.0000  100.0   518.67   642.44  1584.12  1406.42
# 4   1      5  0.0014  0.0000  100.0   518.67   642.51  1587.19  1401.92
#
#    sensor5  ...  sensor16  sensor17  sensor18  sensor19  sensor20  sensor21  \
# 0    14.62  ...      0.03       392      2388     100.0     38.86   23.3735
# 1    14.62  ...      0.03       393      2388     100.0     39.02   23.3916
# 2    14.62  ...      0.03       393      2388     100.0     39.08   23.4166
# 3    14.62  ...      0.03       391      2388     100.0     39.00   23.3737
# 4    14.62  ...      0.03       390      2388     100.0     38.99   23.4130
#
#    sensor22  sensor23  rul_failed  remaining_cycle
# ...

# %%
test_data[test_data['id'] == 1]
# Out:
#     id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0    1      1  0.0023  0.0003  100.0   518.67   643.02  1585.29  1398.21
# 1    1      2 -0.0027 -0.0003  100.0   518.67   641.71  1588.45  1395.42
# 2    1      3  0.0003  0.0001  100.0   518.67   642.46  1586.94  1401.34
# 3    1      4  0.0042  0.0000  100.0   518.67   642.44  1584.12  1406.42
# 4    1      5  0.0014  0.0000  100.0   518.67   642.51  1587.19  1401.92
# 5    1      6  0.0012  0.0003  100.0   518.67   642.11  1579.12  1395.13
# 6    1      7 -0.0000  0.0002  100.0   518.67   642.11  1583.34  1404.84
# 7    1      8  0.0006 -0.0000  100.0   518.67   642.54  1580.89  1400.89
# 8    1      9 -0.0036  0.0000  100.0   518.67   641.88  1593.29  1412.28
# 9    1     10 -0.0025 -0.0001  100.0   518.67   642.07  1585.25  1398.64
# 10   1     11  0.0007 -0.0004  100.0   518.67   642.04  1581.03  1403.83
# 11   1     12  0.0026  0.0003  100.0   518.67   642.54  1587.43  1397.82
# ...

# %%
test_data.isnull().sum()
# Out:
# id                     0
# cycle                  0
# op1                    0
# op2                    0
# op3                    0
# sensor1                0
# sensor2                0
# sensor3                0
# sensor4                0
# sensor5                0
# sensor6                0
# sensor7                0
# sensor8                0
# sensor9                0
# sensor10               0
# sensor11               0
# sensor12               0
# sensor13               0
# sensor14               0
# sensor15               0
# sensor16               0
# sensor17               0
# sensor18               0
# sensor19               0
# sensor20               0
# sensor21               0
# sensor22           13096
# sensor23           13096
# rul_failed             0
# remaining_cycle        0
# dtype: int64

# %%
df_train=train_data.drop(["sensor22","sensor23"],axis=1)
df_test=test_data.drop(["sensor22","sensor23"],axis=1)

# %%
df_test.drop(["rul_failed"],axis=1,inplace=True) ## drop rul_failed col, containing max cycle per engine. 
df_test.head()
# Out:
#    id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0   1      1  0.0023  0.0003  100.0   518.67   643.02  1585.29  1398.21
# 1   1      2 -0.0027 -0.0003  100.0   518.67   641.71  1588.45  1395.42
# 2   1      3  0.0003  0.0001  100.0   518.67   642.46  1586.94  1401.34
# 3   1      4  0.0042  0.0000  100.0   518.67   642.44  1584.12  1406.42
# 4   1      5  0.0014  0.0000  100.0   518.67   642.51  1587.19  1401.92
#
#    sensor5  ...  sensor13  sensor14  sensor15  sensor16  sensor17  sensor18  \
# 0    14.62  ...   2388.03   8125.55    8.4052      0.03       392      2388
# 1    14.62  ...   2388.06   8139.62    8.3803      0.03       393      2388
# 2    14.62  ...   2388.03   8130.10    8.4441      0.03       393      2388
# 3    14.62  ...   2388.05   8132.90    8.3917      0.03       391      2388
# 4    14.62  ...   2388.03   8129.54    8.4031      0.03       390      2388
#
#    sensor19  sensor20  sensor21  remaining_cycle
# ...

# %%
df_train['remaining_cycle'] = df_train.groupby(['id'])['cycle'].transform(max)-df_train['cycle']
df_train
# Out:
#         id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0        1      1 -0.0007 -0.0004  100.0   518.67   641.82  1589.70  1400.60
# 1        1      2  0.0019 -0.0003  100.0   518.67   642.15  1591.82  1403.14
# 2        1      3 -0.0043  0.0003  100.0   518.67   642.35  1587.99  1404.20
# 3        1      4  0.0007  0.0000  100.0   518.67   642.35  1582.79  1401.87
# 4        1      5 -0.0019 -0.0002  100.0   518.67   642.37  1582.85  1406.22
# ...    ...    ...     ...     ...    ...      ...      ...      ...      ...
# 20626  100    196 -0.0004 -0.0003  100.0   518.67   643.49  1597.98  1428.63
# 20627  100    197 -0.0016 -0.0005  100.0   518.67   643.54  1604.50  1433.58
# 20628  100    198  0.0004  0.0000  100.0   518.67   643.42  1602.46  1428.18
# 20629  100    199 -0.0011  0.0003  100.0   518.67   643.23  1605.26  1426.53
# 20630  100    200 -0.0032 -0.0005  100.0   518.67   643.85  1600.38  1432.14
#
# ...

# %%
cycle=50
df_train['label'] = df_train['remaining_cycle'].apply(lambda x: 1 if x <= cycle else 0)
df_test['label'] = df_test['remaining_cycle'].apply(lambda x: 1 if x <= cycle else 0)

# %%
df_test.head()
#df_train.head()
# Out:
#    id  cycle     op1     op2    op3  sensor1  sensor2  sensor3  sensor4  \
# 0   1      1  0.0023  0.0003  100.0   518.67   643.02  1585.29  1398.21
# 1   1      2 -0.0027 -0.0003  100.0   518.67   641.71  1588.45  1395.42
# 2   1      3  0.0003  0.0001  100.0   518.67   642.46  1586.94  1401.34
# 3   1      4  0.0042  0.0000  100.0   518.67   642.44  1584.12  1406.42
# 4   1      5  0.0014  0.0000  100.0   518.67   642.51  1587.19  1401.92
#
#    sensor5  ...  sensor14  sensor15  sensor16  sensor17  sensor18  sensor19  \
# 0    14.62  ...   8125.55    8.4052      0.03       392      2388     100.0
# 1    14.62  ...   8139.62    8.3803      0.03       393      2388     100.0
# 2    14.62  ...   8130.10    8.4441      0.03       393      2388     100.0
# 3    14.62  ...   8132.90    8.3917      0.03       391      2388     100.0
# 4    14.62  ...   8129.54    8.4031      0.03       390      2388     100.0
#
#    sensor20  sensor21  remaining_cycle  label
# ...

# %%
df_train.plot(subplots=True, figsize=(10, 25))
#df_test.plot(subplots= True, figsize=(10,25))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
### Investigate sensor 6, if it's worth removing

test = df_train['sensor6'].unique()
test
# Out:
# array([21.61, 21.6 ])

# %%
### Plot sensor 6
plot_sensor_6 = df_train['sensor6'].plot(figsize=(15,2))
plot_sensor_6 ## remove it
# Out:
# <Axes: >

# %%
#Drop useless independent variables and define dependent variable for training data
y = df_train.label
df_train.drop(['id','cycle', 'op3', 'sensor1','sensor5','sensor6','sensor10','sensor16','sensor18','sensor19', 'remaining_cycle', 'label'],axis=1,inplace=True)
df_train
# Out:
#           op1     op2  sensor2  sensor3  sensor4  sensor7  sensor8  sensor9  \
# 0     -0.0007 -0.0004   641.82  1589.70  1400.60   554.36  2388.06  9046.19
# 1      0.0019 -0.0003   642.15  1591.82  1403.14   553.75  2388.04  9044.07
# 2     -0.0043  0.0003   642.35  1587.99  1404.20   554.26  2388.08  9052.94
# 3      0.0007  0.0000   642.35  1582.79  1401.87   554.45  2388.11  9049.48
# 4     -0.0019 -0.0002   642.37  1582.85  1406.22   554.00  2388.06  9055.15
# ...       ...     ...      ...      ...      ...      ...      ...      ...
# 20626 -0.0004 -0.0003   643.49  1597.98  1428.63   551.43  2388.19  9065.52
# 20627 -0.0016 -0.0005   643.54  1604.50  1433.58   550.86  2388.23  9065.11
# 20628  0.0004  0.0000   643.42  1602.46  1428.18   550.94  2388.24  9065.90
# 20629 -0.0011  0.0003   643.23  1605.26  1426.53   550.68  2388.25  9073.72
# 20630 -0.0032 -0.0005   643.85  1600.38  1432.14   550.79  2388.26  9061.48
#
# ...

# %%
df_test.drop(['id','cycle', 'op3', 'sensor1','sensor5','sensor6','sensor10','sensor16','sensor18','sensor19'], axis = 1, inplace = True)

# %%
df_test
#df_test.label.unique()
# Out:
#           op1     op2  sensor2  sensor3  sensor4  sensor7  sensor8  sensor9  \
# 0      0.0023  0.0003   643.02  1585.29  1398.21   553.90  2388.04  9050.17
# 1     -0.0027 -0.0003   641.71  1588.45  1395.42   554.85  2388.01  9054.42
# 2      0.0003  0.0001   642.46  1586.94  1401.34   554.11  2388.05  9056.96
# 3      0.0042  0.0000   642.44  1584.12  1406.42   554.07  2388.03  9045.29
# 4      0.0014  0.0000   642.51  1587.19  1401.92   554.16  2388.01  9044.55
# ...       ...     ...      ...      ...      ...      ...      ...      ...
# 13091  0.0049  0.0000   643.24  1599.45  1415.79   553.41  2388.02  9142.37
# 13092 -0.0011 -0.0001   643.22  1595.69  1422.05   553.22  2388.05  9140.68
# 13093 -0.0006 -0.0003   643.44  1593.15  1406.82   553.04  2388.11  9146.81
# 13094 -0.0038  0.0001   643.26  1594.99  1419.36   553.37  2388.07  9148.85
# 13095  0.0013  0.0003   642.95  1601.62  1424.99   552.48  2388.06  9155.03
#
# ...

# %%
# Let's check the shape of the datasets

x = df_train # (X transpose X matrix)
x.shape, y.shape 
#----------
# Out:
# ((20631, 16), (20631,))

# %% [markdown]
# ### Creating the model

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=1234)

# %%
print('X_train shape : ',X_train.shape)
print('X_test shape : ',X_test.shape)
print('y_train shape : ',y_train.shape)
print('y_test shape : ',y_test.shape)
# Out:
# X_train shape :  (16504, 16)
# X_test shape :  (4127, 16)
# y_train shape :  (16504,)
# y_test shape :  (4127,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# %%
rf = RandomForestClassifier(n_estimators = 100, 
max_depth = 3, min_samples_leaf = 4, bootstrap = True, 
n_jobs = 1, random_state = 222)
fit = rf.fit(X_train, y_train)

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9319118003392295

# %%
# Tree Visualisation
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

fig = plt.figure(figsize = (10, 10))

def tree_graph_estimator(x: int): #enter estimator
    for i in range(x):
        tree = rf.estimators_[i]
        graph = plot_tree(tree, feature_names=X_train.columns, filled=True, proportion = True)
    display(graph)

tree_graph_estimator(30)
# Out:
# [Text(0.5, 0.875, 'sensor12 <= 520.915\ngini = 0.371\nsamples = 100.0%\nvalue = [0.754, 0.246]'),
#  Text(0.25, 0.625, 'sensor12 <= 520.545\ngini = 0.336\nsamples = 23.4%\nvalue = [0.213, 0.787]'),
#  Text(0.125, 0.375, 'sensor7 <= 553.365\ngini = 0.113\nsamples = 13.6%\nvalue = [0.06, 0.94]'),
#  Text(0.0625, 0.125, 'gini = 0.094\nsamples = 13.4%\nvalue = [0.049, 0.951]'),
#  Text(0.1875, 0.125, 'gini = 0.382\nsamples = 0.2%\nvalue = [0.743, 0.257]'),
#  Text(0.375, 0.375, 'sensor11 <= 47.815\ngini = 0.489\nsamples = 9.8%\nvalue = [0.427, 0.573]'),
#  Text(0.3125, 0.125, 'gini = 0.482\nsamples = 6.6%\nvalue = [0.594, 0.406]'),
#  Text(0.4375, 0.125, 'gini = 0.172\nsamples = 3.2%\nvalue = [0.095, 0.905]'),
#  Text(0.75, 0.625, 'sensor14 <= 8161.51\ngini = 0.151\nsamples = 76.6%\nvalue = [0.918, 0.082]'),
#  Text(0.625, 0.375, 'sensor7 <= 553.025\ngini = 0.093\nsamples = 72.3%\nvalue = [0.951, 0.049]'),
#  Text(0.5625, 0.125, 'gini = 0.312\nsamples = 11.3%\nvalue = [0.807, 0.193]'),
# ...

# %%
#Feature importance plot

sorted_idx = rf.feature_importances_.argsort()
plt.barh(X_train.columns[sorted_idx], rf.feature_importances_[sorted_idx], color = 'lightgreen')
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
from sklearn.model_selection import StratifiedKFold,RandomizedSearchCV
stf_kf=StratifiedKFold(n_splits=5)
import xgboost as xgb
xgb_classifier=xgb.XGBClassifier(n_estimators=1000,n_jobs=-1)
params={
         'learning_rate': np.arange(0.01, 0.11, 0.025),
         'max_depth': np.arange(1, 10, 1),
         'min_child_weight': np.arange(1, 10, 1), 
         'subsample': np.arange( 0.7, 1, 0.05), 
         'gamma': np.arange(0.5, 1, 0.1), 
         'colsample_bytree': np.arange( 0.1, 1, 0.05), 
         'scale_pos_weight': np.arange( 20, 200, 10)}
rs_cv_classifier=RandomizedSearchCV(xgb_classifier,param_distributions=params,cv=stf_kf,n_jobs=-1)
rs_cv_classifier.fit(X_train,y_train)
y_pred=rs_cv_classifier.predict(X_test)
print("Best Parameter: \n",rs_cv_classifier.best_params_)
print("XGBClassifier Acc Score: ",accuracy_score(y_pred,y_test))
# Out:
# Best Parameter:
#  {'subsample': 0.9000000000000001, 'scale_pos_weight': 30, 'min_child_weight': 3, 'max_depth': 6, 'learning_rate': 0.085, 'gamma': 0.6, 'colsample_bytree': 0.3500000000000001}
# XGBClassifier Acc Score:  0.9200387690816574

# %%
## Model testing on Validation set -> df_test

df_test_pred = rs_cv_classifier.predict(df_test.drop(['remaining_cycle','label'],axis=1))
cm=confusion_matrix(df_test.iloc[:,-1], df_test_pred, labels=None, sample_weight=None)

# %%
print("Test Accuracy Score: ", accuracy_score(df_test.iloc[:,-1],df_test_pred))
# Out:
# Test Accuracy Score:  0.955024434941967

# %%
sb.heatmap(cm, annot_kws={'size':20}, annot= True, fmt='d', cmap='PiYG')
# Out:
# <Axes: >
